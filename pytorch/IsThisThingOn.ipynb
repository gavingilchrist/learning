# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name())
# Out:
# True
# NVIDIA GeForce GTX 1660 Ti with Max-Q Design

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.4874, 0.1093, 0.0435],
#         [0.6933, 0.5425, 0.2964],
#         [0.5371, 0.3033, 0.0940],
#         [0.1478, 0.6693, 0.1655],
#         [0.3311, 0.8788, 0.5476]])
