# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name())
# Out:
# True
# NVIDIA GeForce GTX 1660 Ti with Max-Q Design

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.2920, 0.9734, 0.6928],
#         [0.8662, 0.0795, 0.1947],
#         [0.2717, 0.2201, 0.8684],
#         [0.3161, 0.2614, 0.2806],
#         [0.9673, 0.6532, 0.6346]])
